# %%
import csv
import cv2
import numpy as np
import h5py
import json
import numpy as np

activation_relu = 'relu'

lines = []
with open('more_training_data/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
        
images = []
measurements = []
for line in lines:
    source_path = line[0]
    filename = source_path.split('/')[-1]
    current_path = './more_training_data/IMG/' + filename
    image = cv2.imread(current_path)
    images.append(image)
    measurement = line[3]
    measurements.append(measurement)
    
augmented_images, augmented_measurements = [], []
for image, measurement in zip(images, measurements):
    augmented_images.append(image)
    augmented_measurements.append(measurement)
    augmented_images.append(cv2.flip(image,1))
    augmented_measurements.append(float(measurement)*-1.0)

X_train = np.array(augmented_images)
Y_train = np.array(augmented_measurements)

from keras.models import Sequential
from keras.layers import Flatten, Dense, Lambda, Cropping2D, Activation
from keras.layers.convolutional import Convolution2D
from keras.layers import MaxPooling2D
from keras.optimizers import Adam

model = Sequential()
model.add(Lambda(lambda x: x / 255.0 - 0.5, input_shape=(160,320,3)))
model.add(Cropping2D(cropping=((85,25),(2,2))))
# starts with five convolutional and maxpooling layers
model.add(Convolution2D(24, 5, 5, border_mode='same', subsample=(2, 2)))
model.add(Activation(activation_relu))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(36, 5, 5, border_mode='same', subsample=(2, 2)))
model.add(Activation(activation_relu))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(48, 5, 5, border_mode='same', subsample=(2, 2)))
model.add(Activation(activation_relu))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(64, 3, 3, border_mode='same', subsample=(1, 1)))
model.add(Activation(activation_relu))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(64, 3, 3, border_mode='same', subsample=(1, 1)))
model.add(Activation(activation_relu))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Flatten())

# Next, five fully connected layers
model.add(Dense(1000))
model.add(Activation(activation_relu))

model.add(Dense(100))
model.add(Activation(activation_relu))

model.add(Dense(50))
model.add(Activation(activation_relu))

model.add(Dense(10))
model.add(Activation(activation_relu))

model.add(Dense(1))

model.summary()

model.compile(optimizer=Adam(0.0001), loss="mse", )

print(X_train.shape)
print(Y_train.shape)

model.compile(loss='mse', optimizer='adam')
model.fit(X_train, Y_train, validation_split=0.2, shuffle=True, nb_epoch=3)
model.save('model.h5', True)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_2 (Lambda)                (None, 160, 320, 3)   0           lambda_input_2[0][0]
# ____________________________________________________________________________________________________
# cropping2d_2 (Cropping2D)        (None, 50, 316, 3)    0           lambda_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)  (None, 25, 158, 24)   1824        cropping2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 25, 158, 24)   0           convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_6 (MaxPooling2D)    (None, 24, 157, 24)   0           activation_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)  (None, 12, 79, 36)    21636       maxpooling2d_6[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 12, 79, 36)    0           convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_7 (MaxPooling2D)    (None, 11, 78, 36)    0           activation_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 6, 39, 48)     43248       maxpooling2d_7[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 6, 39, 48)     0           convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_8 (MaxPooling2D)    (None, 5, 38, 48)     0           activation_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)  (None, 5, 38, 64)     27712       maxpooling2d_8[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 5, 38, 64)     0           convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_9 (MaxPooling2D)    (None, 4, 37, 64)     0           activation_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D) (None, 4, 37, 64)     36928       maxpooling2d_9[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 4, 37, 64)     0           convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_10 (MaxPooling2D)   (None, 3, 36, 64)     0           activation_14[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 6912)          0           maxpooling2d_10[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 1000)          6913000     flatten_2[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 1000)          0           dense_6[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                  (None, 100)           100100      activation_15[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 100)           0           dense_7[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 50)            5050        activation_16[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 50)            0           dense_8[0][0]
# ____________________________________________________________________________________________________
# dense_9 (Dense)                  (None, 10)            510         activation_17[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 10)            0           dense_9[0][0]
# ____________________________________________________________________________________________________
# dense_10 (Dense)                 (None, 1)             11          activation_18[0][0]
# ====================================================================================================
# Total params: 7,150,019
# Trainable params: 7,150,019
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# (5264, 160, 320, 3)
# (5264,)
# Train on 4211 samples, validate on 1053 samples
# Epoch 1/3
# 4211/4211 [==============================] - 75s - loss: 0.0118 - val_loss: 0.0164
# Epoch 2/3
# 4211/4211 [==============================] - 70s - loss: 0.0117 - val_loss: 0.0164
# Epoch 3/3
# 4211/4211 [==============================] - 79s - loss: 0.0117 - val_loss: 0.0164
